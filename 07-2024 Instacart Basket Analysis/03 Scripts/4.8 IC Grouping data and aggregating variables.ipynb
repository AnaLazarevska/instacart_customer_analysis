# %% [markdown]
# # 4.8 Grouping data and aggregating variables

# %% [markdown]
# ## Contents:
#
# 01. Import libraries
# 02. Import datasets¶
# 03. Group data and aggregate mean
# 04. Create loyalty flag for existing customers using the transform() and loc() functions
# 05. Identify spending habits of the three types of customers
# 06. Identify average spending price for each customers
# 07. Identify user's ordering frequency
# 08. Export dataframes

# %% [markdown]
# ## 01. Import libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Import datasets

# %%
# import datasets

path = r'/Users/analazarevska/Documents/CAREER FOUNDRY/Data Analytics Program/Data Immersion/A4, Python Fundamentals for Data Analysts/Achievement 4/07-2024 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new1.pkl'))

# %% [markdown]
# ## 03. Group data and aggregate mean

# %%
# first step: check shape of dataframe

ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
# second step: check columns and first rows of dataframe

ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# ...

# %%
# group data by departnemt_id and find aggregated mean of order_number column

ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# ### How is the mean result different for whole dataframe and subset?
#
# The means for all 21 departments are similar when applied to the whole dataframe and to the subset of 1 million rows. The subset contained the first 6,474 customers, while the whole dataframe includes 206,209 customers. It means that the purchasing interests of the customers are similar around the dataframe.

# %% [markdown]
# ## 04. Create loyalty flag for existing customers using the transform() and loc() functions

# %%
# create max_order column with results from transform() function on the “order_number” column grouped by user_id

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/cd/qrn0mbpn33xd1226hwqc_kn00000gn/T/ipykernel_99112/2082692073.py:3: FutureWarning: The provided callable <function max at 0x10493fc40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# ...

# %%
# create flag for loyalty labels

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both
#
# ...

# %% [markdown]
# ## 05. Identify spending habits of the three types of customers

# %%
# find mean prices grouped by customer category

ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal customer      10.386336
# New customer        13.294670
# Regular customer    12.495717
# Name: prices, dtype: float64

# %% [markdown]
# ### How do prices differ between customer categories?
#
# Even though there are fewer new customers than both loyatly and regular customers, they purchase more expensive products on average than the other two types of customers. The products they buy are 1 dollar more expensive than the products that the regular customers buy. The loyalty customers purchase the cheapest products, spending 10 dollars on average.

# %% [markdown]
# ## 06. Identify average spending price for each customers

# %%
# create spending_flag column for each user based on the average orders price

ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/cd/qrn0mbpn33xd1226hwqc_kn00000gn/T/ipykernel_99112/1374057835.py:3: FutureWarning: The provided callable <function mean at 0x10495c680> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both
#
# ...

# %%
# create spending flag function for each user based on average price

ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts()
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404854   2977660   206209            13                   1
# 32404855   2977660   206209            13                   1
# 32404856   2977660   206209            13                   1
# 32404857   2977660   206209            13                   1
# 32404858   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32404854                 12                     7.0       14197
# 32404855                 12                     7.0       38730
# 32404856                 12                     7.0       31477
# 32404857                 12                     7.0        6567
# 32404858                 12                     7.0       22920
#
#           add_to_cart_order  reordered _merge  ... department_id  prices  \
# 32404854                  5          1   both  ...             9     5.6
# ...

# %% [markdown]
# ## 07. Identify user's ordering frequency

# %%
# Create order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

ords_prods_merge['frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/cd/qrn0mbpn33xd1226hwqc_kn00000gn/T/ipykernel_99112/2361308739.py:3: FutureWarning: The provided callable <function median at 0x104a73380> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both
#
#    ... prices        price_label     busiest_day    busiest_days  \
# ...

# %%
# create frequency flag function for each user based on median days_since_prior_order

ords_prods_merge.loc[ords_prods_merge['frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['frequency'] > 10) & (ords_prods_merge['frequency'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts()
# Out:
# frequency_flag
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both
#
#    ...        price_label     busiest_day    busiest_days  \
# ...

# %% [markdown]
# ## 08. Export dataframes

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_new2.pkl'))
