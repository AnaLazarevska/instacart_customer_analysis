# %% [markdown]
# # 4.8 Grouping data and aggregating variables prep

# %% [markdown]
# ## Contents:
#
# 01. Import libraries
# 02. Import datasets¶
# 03. Create subset
# 04. Grouping data
# 04. a) Aggregating data with agg()
# 04. b) Aggregating data with transform()
# 05. Deriving columns with loc()
# 06. Export dataframe

# %% [markdown]
# ## 01. Import libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Import datasets

# %%
# import datasets

path = r'/Users/analazarevska/Documents/CAREER FOUNDRY/Data Analytics Program/Data Immersion/A4, Python Fundamentals for Data Analysts/Achievement 4/07-2024 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new.pkl'))

# %% [markdown]
# ## 03. Create subset

# %%
# create subset for first 1 million rows

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()

# %% [markdown]
# ## 04. Grouping data

# %% [markdown]
# ## 04a. Aggregating data with agg()

# %%
# step 1: split the data into groups based on some criteria

df.groupby('product_name')

# %%
# step 2: apply a function to each group separately

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# alternative function to agg()

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# perform multiple aggregations

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
# step 3: combine the results into a dataframe or alternative data structure or create a new column in the current dataframe

# %% [markdown]
# ## 04b. Aggregating data with transform()

# %%
# step 1: split the data into groups based on the “user_id” column
# step 2: apply the transform() function on the “order_number” column to generate the maximum orders for each user
# step 3: create a new column, “max_order,” into which you’ll place the results of your aggregation
 
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/cd/qrn0mbpn33xd1226hwqc_kn00000gn/T/ipykernel_284/3793724233.py:5: FutureWarning: The provided callable <function max at 0x107ac3c40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      0.0         196                  1          0   both
# 1                      0.0       14084                  2          0   both
# 2                      0.0       12427                  3          0   both
# 3                      0.0       26088                  4          0   both
# 4                      0.0       26405                  5          0   both
# ..                     ...         ...                ...        ...    ...
# 95                     8.0       21150                 13          0   both
# 96                     8.0       47144                  1          0   both
# 97                     8.0        5322                  2          0   both
# 98                     8.0       17224                  3          0   both
# 99                     8.0       38656                  4          0   both
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# ..                                                ...       ...
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices        price_label     busiest_day  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1              16    12.5  Mid-range product  Regularly busy
# 2              19     4.4  Low-range product  Regularly busy
# 3              19     4.7  Low-range product  Regularly busy
# 4              17     1.0  Low-range product  Regularly busy
# ..            ...     ...                ...             ...
# 95              1     5.9  Mid-range product  Regularly busy
# 96             16    14.0  Mid-range product  Regularly busy
# 97             19     2.9  Low-range product  Regularly busy
# 98             19     1.6  Low-range product  Regularly busy
# 99             19     3.4  Low-range product  Regularly busy
#
#            busiest_days busiest_period_of_day  max_order
# 0        Regularly busy        Average orders         10
# 1        Regularly busy        Average orders         10
# 2        Regularly busy        Average orders         10
# 3        Regularly busy        Average orders         10
# 4        Regularly busy        Average orders         10
# ..                  ...                   ...        ...
# 95       Regularly busy           Most orders         14
# 96  Two least busy days           Most orders         14
# 97  Two least busy days           Most orders         14
# 98  Two least busy days           Most orders         14
# 99  Two least busy days           Most orders         14
#
# [100 rows x 19 columns]

# %%
# remove the restriction to displaying many rows

pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
# 50   2550362        1            10                   4                  8
# 51   2550362        1            10                   4                  8
# 52   2550362        1            10                   4                  8
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
# 62   2168274        2             1                   2                 11
# 63   2168274        2             1                   2                 11
# 64   2168274        2             1                   2                 11
# 65   2168274        2             1                   2                 11
# 66   2168274        2             1                   2                 11
# 67   2168274        2             1                   2                 11
# 68   2168274        2             1                   2                 11
# 69   2168274        2             1                   2                 11
# 70   2168274        2             1                   2                 11
# 71   2168274        2             1                   2                 11
# 72   1501582        2             2                   5                 10
# 73   1501582        2             2                   5                 10
# 74   1501582        2             2                   5                 10
# 75   1501582        2             2                   5                 10
# 76   1501582        2             2                   5                 10
# 77   1501582        2             2                   5                 10
# 78   1901567        2             3                   1                 10
# 79   1901567        2             3                   1                 10
# 80   1901567        2             3                   1                 10
# 81   1901567        2             3                   1                 10
# 82   1901567        2             3                   1                 10
# 83    738281        2             4                   2                 10
# 84    738281        2             4                   2                 10
# 85    738281        2             4                   2                 10
# 86    738281        2             4                   2                 10
# 87    738281        2             4                   2                 10
# 88    738281        2             4                   2                 10
# 89    738281        2             4                   2                 10
# 90    738281        2             4                   2                 10
# 91    738281        2             4                   2                 10
# 92    738281        2             4                   2                 10
# 93    738281        2             4                   2                 10
# 94    738281        2             4                   2                 10
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      0.0         196                  1          0   both
# 1                      0.0       14084                  2          0   both
# 2                      0.0       12427                  3          0   both
# 3                      0.0       26088                  4          0   both
# 4                      0.0       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
# 25                    28.0       10326                  5          0   both
# 26                    28.0       17122                  6          0   both
# 27                    28.0       41787                  7          0   both
# 28                    28.0       13176                  8          1   both
# 29                    19.0         196                  1          1   both
# 30                    19.0       12427                  2          1   both
# 31                    19.0       10258                  3          1   both
# 32                    19.0       25133                  4          1   both
# 33                    20.0         196                  1          1   both
# 34                    20.0       10258                  2          1   both
# 35                    20.0       12427                  3          1   both
# 36                    20.0       25133                  4          1   both
# 37                    20.0       13032                  5          1   both
# 38                    14.0       12427                  1          1   both
# 39                    14.0         196                  2          1   both
# 40                    14.0       10258                  3          1   both
# 41                    14.0       25133                  4          1   both
# 42                    14.0       46149                  5          0   both
# 43                    14.0       49235                  6          0   both
# 44                     0.0       49235                  1          1   both
# 45                     0.0       46149                  2          1   both
# 46                     0.0       25133                  3          1   both
# 47                     0.0         196                  4          1   both
# 48                     0.0       10258                  5          1   both
# 49                     0.0       12427                  6          1   both
# 50                    30.0         196                  1          1   both
# 51                    30.0       46149                  2          1   both
# 52                    30.0       39657                  3          0   both
# 53                    30.0       38928                  4          0   both
# 54                    30.0       25133                  5          1   both
# 55                    30.0       10258                  6          1   both
# 56                    30.0       35951                  7          0   both
# 57                    30.0       13032                  8          1   both
# 58                    30.0       12427                  9          1   both
# 59                     0.0       32792                  1          0   both
# 60                     0.0       47766                  2          0   both
# 61                     0.0       20574                  3          0   both
# 62                     0.0       12000                  4          0   both
# 63                     0.0       48110                  5          0   both
# 64                     0.0       22474                  6          0   both
# 65                     0.0       16589                  7          0   both
# 66                     0.0       35917                  8          0   both
# 67                     0.0       27344                  9          0   both
# 68                     0.0       30489                 10          0   both
# 69                     0.0       27966                 11          0   both
# 70                     0.0       13176                 12          0   both
# 71                     0.0       45066                 13          0   both
# 72                    10.0       16797                  1          0   both
# 73                    10.0       47526                  2          0   both
# 74                    10.0        8479                  3          0   both
# 75                    10.0       47766                  4          1   both
# 76                    10.0       19051                  5          0   both
# 77                    10.0        8138                  6          0   both
# 78                     3.0       47766                  1          1   both
# 79                     3.0       32792                  2          1   both
# 80                     3.0       20574                  3          1   both
# 81                     3.0        7781                  4          0   both
# 82                     3.0       28874                  5          0   both
# 83                     8.0       49451                  1          0   both
# 84                     8.0       32792                  2          1   both
# 85                     8.0       32139                  3          0   both
# 86                     8.0       34688                  4          0   both
# 87                     8.0       36735                  5          0   both
# 88                     8.0       37646                  6          0   both
# 89                     8.0       22829                  7          0   both
# 90                     8.0       24852                  8          0   both
# 91                     8.0       47209                  9          0   both
# 92                     8.0       33276                 10          0   both
# 93                     8.0       45613                 11          0   both
# 94                     8.0        9681                 12          0   both
# 95                     8.0       21150                 13          0   both
# 96                     8.0       47144                  1          0   both
# 97                     8.0        5322                  2          0   both
# 98                     8.0       17224                  3          0   both
# 99                     8.0       38656                  4          0   both
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# 5                                                Soda        77
# 6                                          Pistachios       117
# 7                                 Original Beef Jerky        23
# 8                              Bag of Organic Bananas        24
# 9                          Aged White Cheddar Popcorn        23
# 10                              Cinnamon Toast Crunch       121
# 11                                               Soda        77
# 12                                Original Beef Jerky        23
# 13                                         Pistachios       117
# 14                              Organic String Cheese        21
# 15                               Creamy Almond Butter        88
# 16                                               Soda        77
# 17                                Original Beef Jerky        23
# 18                                         Pistachios       117
# 19                              Organic String Cheese        21
# 20                   XL Pick-A-Size Paper Towel Rolls        54
# 21                                               Soda        77
# 22                                Original Beef Jerky        23
# 23                                         Pistachios       117
# 24                              Organic String Cheese        21
# 25                                Organic Fuji Apples        24
# 26                                  Honeycrisp Apples        24
# 27                                     Bartlett Pears        24
# 28                             Bag of Organic Bananas        24
# 29                                               Soda        77
# 30                                Original Beef Jerky        23
# 31                                         Pistachios       117
# 32                              Organic String Cheese        21
# 33                                               Soda        77
# 34                                         Pistachios       117
# 35                                Original Beef Jerky        23
# 36                              Organic String Cheese        21
# 37                              Cinnamon Toast Crunch       121
# 38                                Original Beef Jerky        23
# 39                                               Soda        77
# 40                                         Pistachios       117
# 41                              Organic String Cheese        21
# 42                                  Zero Calorie Cola        77
# 43                                Organic Half & Half        53
# 44                                Organic Half & Half        53
# 45                                  Zero Calorie Cola        77
# 46                              Organic String Cheese        21
# 47                                               Soda        77
# 48                                         Pistachios       117
# 49                                Original Beef Jerky        23
# 50                                               Soda        77
# 51                                  Zero Calorie Cola        77
# 52                             Milk Chocolate Almonds        45
# 53                           0% Greek Strained Yogurt       120
# 54                              Organic String Cheese        21
# 55                                         Pistachios       117
# 56                    Organic Unsweetened Almond Milk        91
# 57                              Cinnamon Toast Crunch       121
# 58                                Original Beef Jerky        23
# 59                     Chipotle Beef & Pork Realstick        23
# 60                                    Organic Avocado        24
# 61                                     Roasted Turkey        96
# 62           Baked Organic Sea Salt Crunchy Pea Snack        72
# 63            Thin Stackers Brown Rice Lightly Salted        78
# 64                     Cheddar Bunnies Snack Crackers        78
# 65                                     Plantain Chips       107
# 66                   Organic Just Concord Grape Juice        98
# 67                               Uncured Genoa Salami        96
# 68                                    Original Hummus        67
# 69                                Organic Raspberries       123
# 70                             Bag of Organic Bananas        24
# 71                                   Honeycrisp Apple        24
# 72                                       Strawberries        24
# 73                                    Goat Cheese Log        21
# 74              Original Black Box Tablewater Cracker        78
# 75                                    Organic Avocado        24
# 76               Pita Chips, Simply Naked, Party Size       107
# 77                                 Traditional Hummus        67
# 78                                    Organic Avocado        24
# 79                     Chipotle Beef & Pork Realstick        23
# 80                                     Roasted Turkey        96
# 81  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 82                                 Carrot Ginger Soup         1
# 83                              Artichoke Spinach Dip        67
# 84                     Chipotle Beef & Pork Realstick        23
# 85                            Hommus Classic Original        67
# 86  Good Belly Probiotics Juice Drink Blueberry Ac...        31
# 87              Organic Roasted Sliced Chicken Breast        96
# 88                                Organic Gala Apples        24
# 89          Multigrain Flax Seeded Flatbread Crackers        78
# 90                                             Banana        24
# 91                               Organic Hass Avocado        24
# 92                              Kalamata Olive Spread        67
# 93                                           Pad Thai        38
# 94  Chicken Tikka Masala with Cumin Infused Basmat...        38
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices        price_label     busiest_day  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1              16    12.5  Mid-range product  Regularly busy
# 2              19     4.4  Low-range product  Regularly busy
# 3              19     4.7  Low-range product  Regularly busy
# 4              17     1.0  Low-range product  Regularly busy
# 5               7     9.0  Mid-range product  Regularly busy
# 6              19     3.0  Low-range product  Regularly busy
# 7              19     4.4  Low-range product  Regularly busy
# 8               4    10.3  Mid-range product  Regularly busy
# 9              19     4.7  Low-range product  Regularly busy
# 10             14     4.0  Low-range product  Regularly busy
# 11              7     9.0  Mid-range product  Regularly busy
# 12             19     4.4  Low-range product  Regularly busy
# 13             19     3.0  Low-range product  Regularly busy
# 14             16     8.6  Mid-range product  Regularly busy
# 15             13     3.2  Low-range product  Regularly busy
# 16              7     9.0  Mid-range product      Least busy
# 17             19     4.4  Low-range product      Least busy
# 18             19     3.0  Low-range product      Least busy
# 19             16     8.6  Mid-range product      Least busy
# 20             17     1.0  Low-range product      Least busy
# 21              7     9.0  Mid-range product      Least busy
# 22             19     4.4  Low-range product      Least busy
# 23             19     3.0  Low-range product      Least busy
# 24             16     8.6  Mid-range product      Least busy
# 25              4     2.7  Low-range product      Least busy
# 26              4    14.0  Mid-range product      Least busy
# 27              4     5.0  Low-range product      Least busy
# 28              4    10.3  Mid-range product      Least busy
# 29              7     9.0  Mid-range product  Regularly busy
# 30             19     4.4  Low-range product  Regularly busy
# 31             19     3.0  Low-range product  Regularly busy
# 32             16     8.6  Mid-range product  Regularly busy
# 33              7     9.0  Mid-range product  Regularly busy
# 34             19     3.0  Low-range product  Regularly busy
# 35             19     4.4  Low-range product  Regularly busy
# 36             16     8.6  Mid-range product  Regularly busy
# 37             14     4.0  Low-range product  Regularly busy
# 38             19     4.4  Low-range product  Regularly busy
# 39              7     9.0  Mid-range product  Regularly busy
# 40             19     3.0  Low-range product  Regularly busy
# 41             16     8.6  Mid-range product  Regularly busy
# 42              7    13.4  Mid-range product  Regularly busy
# 43             16     1.8  Low-range product  Regularly busy
# 44             16     1.8  Low-range product  Regularly busy
# 45              7    13.4  Mid-range product  Regularly busy
# 46             16     8.6  Mid-range product  Regularly busy
# 47              7     9.0  Mid-range product  Regularly busy
# 48             19     3.0  Low-range product  Regularly busy
# 49             19     4.4  Low-range product  Regularly busy
# 50              7     9.0  Mid-range product      Least busy
# 51              7    13.4  Mid-range product      Least busy
# 52             19     6.8  Mid-range product      Least busy
# 53             16    12.6  Mid-range product      Least busy
# 54             16     8.6  Mid-range product      Least busy
# 55             19     3.0  Low-range product      Least busy
# 56             16     1.3  Low-range product      Least busy
# 57             14     4.0  Low-range product      Least busy
# 58             19     4.4  Low-range product      Least busy
# 59             19     5.2  Mid-range product  Regularly busy
# 60              4     6.3  Mid-range product  Regularly busy
# 61             20     2.3  Low-range product  Regularly busy
# 62             13    10.9  Mid-range product  Regularly busy
# 63             19     2.7  Low-range product  Regularly busy
# 64             19     4.1  Low-range product  Regularly busy
# 65             19     5.0  Low-range product  Regularly busy
# 66              7     9.4  Mid-range product  Regularly busy
# 67             20    14.8  Mid-range product  Regularly busy
# 68             20     7.5  Mid-range product  Regularly busy
# 69              4     4.4  Low-range product  Regularly busy
# 70              4    10.3  Mid-range product  Regularly busy
# 71              4     2.5  Low-range product  Regularly busy
# 72              4     1.3  Low-range product  Regularly busy
# 73             16     2.0  Low-range product  Regularly busy
# 74             19     3.5  Low-range product  Regularly busy
# 75              4     6.3  Mid-range product  Regularly busy
# 76             19     3.9  Low-range product  Regularly busy
# 77             20     2.0  Low-range product  Regularly busy
# 78              4     6.3  Mid-range product  Regularly busy
# 79             19     5.2  Mid-range product  Regularly busy
# 80             20     2.3  Low-range product  Regularly busy
# 81             16     6.6  Mid-range product  Regularly busy
# 82             20     6.2  Mid-range product  Regularly busy
# 83             20     7.1  Mid-range product  Regularly busy
# 84             19     5.2  Mid-range product  Regularly busy
# 85             20     7.5  Mid-range product  Regularly busy
# 86              7     5.8  Mid-range product  Regularly busy
# 87             20     8.9  Mid-range product  Regularly busy
# 88              4     9.1  Mid-range product  Regularly busy
# 89             19     5.5  Mid-range product  Regularly busy
# 90              4    12.3  Mid-range product  Regularly busy
# 91              4     4.0  Low-range product  Regularly busy
# 92             20    10.8  Mid-range product  Regularly busy
# 93              1    12.6  Mid-range product  Regularly busy
# 94              1     2.0  Low-range product  Regularly busy
# 95              1     5.9  Mid-range product  Regularly busy
# 96             16    14.0  Mid-range product  Regularly busy
# 97             19     2.9  Low-range product  Regularly busy
# 98             19     1.6  Low-range product  Regularly busy
# 99             19     3.4  Low-range product  Regularly busy
#
#            busiest_days busiest_period_of_day  max_order
# 0        Regularly busy        Average orders         10
# 1        Regularly busy        Average orders         10
# 2        Regularly busy        Average orders         10
# 3        Regularly busy        Average orders         10
# 4        Regularly busy        Average orders         10
# 5   Two least busy days        Average orders         10
# 6   Two least busy days        Average orders         10
# 7   Two least busy days        Average orders         10
# 8   Two least busy days        Average orders         10
# 9   Two least busy days        Average orders         10
# 10  Two least busy days        Average orders         10
# 11  Two least busy days           Most orders         10
# 12  Two least busy days           Most orders         10
# 13  Two least busy days           Most orders         10
# 14  Two least busy days           Most orders         10
# 15  Two least busy days           Most orders         10
# 16  Two least busy days        Average orders         10
# 17  Two least busy days        Average orders         10
# 18  Two least busy days        Average orders         10
# 19  Two least busy days        Average orders         10
# 20  Two least busy days        Average orders         10
# 21  Two least busy days           Most orders         10
# 22  Two least busy days           Most orders         10
# 23  Two least busy days           Most orders         10
# 24  Two least busy days           Most orders         10
# 25  Two least busy days           Most orders         10
# 26  Two least busy days           Most orders         10
# 27  Two least busy days           Most orders         10
# 28  Two least busy days           Most orders         10
# 29       Regularly busy        Average orders         10
# 30       Regularly busy        Average orders         10
# 31       Regularly busy        Average orders         10
# 32       Regularly busy        Average orders         10
# 33     Two busiest days           Most orders         10
# 34     Two busiest days           Most orders         10
# 35     Two busiest days           Most orders         10
# 36     Two busiest days           Most orders         10
# 37     Two busiest days           Most orders         10
# 38     Two busiest days           Most orders         10
# 39     Two busiest days           Most orders         10
# 40     Two busiest days           Most orders         10
# 41     Two busiest days           Most orders         10
# 42     Two busiest days           Most orders         10
# 43     Two busiest days           Most orders         10
# 44     Two busiest days           Most orders         10
# 45     Two busiest days           Most orders         10
# 46     Two busiest days           Most orders         10
# 47     Two busiest days           Most orders         10
# 48     Two busiest days           Most orders         10
# 49     Two busiest days           Most orders         10
# 50  Two least busy days        Average orders         10
# 51  Two least busy days        Average orders         10
# 52  Two least busy days        Average orders         10
# 53  Two least busy days        Average orders         10
# 54  Two least busy days        Average orders         10
# 55  Two least busy days        Average orders         10
# 56  Two least busy days        Average orders         10
# 57  Two least busy days        Average orders         10
# 58  Two least busy days        Average orders         10
# 59       Regularly busy           Most orders         14
# 60       Regularly busy           Most orders         14
# 61       Regularly busy           Most orders         14
# 62       Regularly busy           Most orders         14
# 63       Regularly busy           Most orders         14
# 64       Regularly busy           Most orders         14
# 65       Regularly busy           Most orders         14
# 66       Regularly busy           Most orders         14
# 67       Regularly busy           Most orders         14
# 68       Regularly busy           Most orders         14
# 69       Regularly busy           Most orders         14
# 70       Regularly busy           Most orders         14
# 71       Regularly busy           Most orders         14
# 72       Regularly busy           Most orders         14
# 73       Regularly busy           Most orders         14
# 74       Regularly busy           Most orders         14
# 75       Regularly busy           Most orders         14
# 76       Regularly busy           Most orders         14
# 77       Regularly busy           Most orders         14
# 78     Two busiest days           Most orders         14
# 79     Two busiest days           Most orders         14
# 80     Two busiest days           Most orders         14
# 81     Two busiest days           Most orders         14
# 82     Two busiest days           Most orders         14
# 83       Regularly busy           Most orders         14
# 84       Regularly busy           Most orders         14
# 85       Regularly busy           Most orders         14
# 86       Regularly busy           Most orders         14
# 87       Regularly busy           Most orders         14
# 88       Regularly busy           Most orders         14
# 89       Regularly busy           Most orders         14
# 90       Regularly busy           Most orders         14
# 91       Regularly busy           Most orders         14
# 92       Regularly busy           Most orders         14
# 93       Regularly busy           Most orders         14
# 94       Regularly busy           Most orders         14
# 95       Regularly busy           Most orders         14
# 96  Two least busy days           Most orders         14
# 97  Two least busy days           Most orders         14
# 98  Two least busy days           Most orders         14
# 99  Two least busy days           Most orders         14

# %% [markdown]
# ## 05. Deriving columns with loc()

# %%
# create flag for loyalty labels

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# check value counts of new column

ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# inspect several columns

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# ## 11. Export dataframe

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_new1.pkl'))
